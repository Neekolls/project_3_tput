# %%
import tput
import importlib

print(tput.__file__)
print(dir(tput))

importlib.reload(tput)
from tput import quick_report
print(quick_report)
import sys
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install scikit-learn
# Out:
# D:\Documents\Data\Projet 3\tput\tput\__init__.py
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'core', 'quick_report', 'report']
# <function quick_report at 0x000002E876398040>
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tput import quick_report
import pandas as pd

df = pd.read_csv("../animals.csv", sep=";")
report = quick_report(df, target="SalePrice")
report.show()
# Out:
# === TPUT REPORT — COLUMN VIEW ===
#
# --- GLOBAL ---
#   shape      : 1011 rows x 11 columns
#   duplicates : 167 duplicated rows (16.52%)
#
# --- COLUMN: Animal type  [str] ---
#   nulls          : 20 (1.98%)
#   n_unique       : 13
#   mode           : 'red squirrel' (543 occurrences)
#   top_values     : 'red squirrel': 543  |  'hedgehog': 274  |  'lynx': 61  |  'European bison': 49  (+9 more)
#   bottom_values  : 'European bisson': 4  |  'European buster': 4  |  'ledgehod': 3  |  'wedgehod': 1
#   case_collisions: none
#   nan_analysis   : MCAR -> impute (mode)
#   type_issues    : keep_as_text  |  numeric_ratio=0.0  datetime_ratio=0.0
#   feature_quality: ok
#   cat_association: strong assoc with 'Animal name' (V=0.4622, p=0.0001)
#
# --- COLUMN: Country  [str] ---
#   nulls          : 12 (1.19%)
#   n_unique       : 15
#   mode           : 'Poland' (291 occurrences)
#   top_values     : 'Poland': 291  |  'Germany': 176  |  'Slovakia': 151  |  'Hungary': 146  (+11 more)
# ...

# %%
df = pd.read_csv("../churn.csv")
report = quick_report(df, target="Churn")
report.show()
# Out:
# === TPUT REPORT — COLUMN VIEW ===
#
# --- GLOBAL ---
#   shape      : 7043 rows x 21 columns
#   duplicates : none
#
# --- COLUMN: customerID  [str] ---
#   nulls          : 0 (0.0%)
#   n_unique       : 7043
#   mode           : ['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', '7795-CFOCW', '9237-HQITU'] ... +7038 more (ex-aequo, 1 each)
#   top_values     : '7590-VHVEG': 1  |  '5575-GNVDE': 1  |  '3668-QPYBK': 1  |  '7795-CFOCW': 1  (+16 more)
#   bottom_values  : '2234-XADUH': 1  |  '4801-JZAZL': 1  |  '8361-LTMKD': 1  |  '3186-AJIEK': 1
#   case_collisions: none
#   type_issues    : keep_as_text  |  numeric_ratio=0.0  datetime_ratio=0.0
#   feature_quality: potential_id — unique ratio=100.0%
#
# --- COLUMN: gender  [str] ---
#   nulls          : 0 (0.0%)
#   n_unique       : 2
#   mode           : 'Male' (3555 occurrences)
#   top_values     : 'Male': 3555  |  'Female': 3488
#   bottom_values  : 'Male': 3555  |  'Female': 3488
#   case_collisions: none
# ...

# %%
df = pd.read_csv("../housing.csv")
report = quick_report(df, target="SalePrice", feature_display=False)
report.show()
# Out:
# === TPUT REPORT ===
#
# Shape: 1460 rows x 81 columns
#
# --- OVERVIEW ---
# n_rows: 1460
# n_cols: 81
# ...

# %%
df = pd.read_csv("../titanic.csv")
report = quick_report(df, target="Survived", feature_display=False)
report.show()
# Out:
# === TPUT REPORT ===
#
# Shape: 891 rows x 12 columns
#
# --- OVERVIEW ---
# n_rows: 891
# n_cols: 12
# columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# dtypes: {'PassengerId': 'int64', 'Survived': 'int64', 'Pclass': 'int64', 'Name': 'str', 'Sex': 'str', 'Age': 'float64', 'SibSp': 'int64', 'Parch': 'int64', 'Ticket': 'str', 'Fare': 'float64', 'Cabin': 'str', 'Embarked': 'str'}
#
# --- FEATURE_QUALITY ---
#
# Column: Survived
#   [low_cardinality] 2 unique values: [0, 1]
#
# Column: Pclass
#   [low_cardinality] 3 unique values: [1, 2, 3]
#
# Column: SibSp
#   [low_cardinality] 7 unique values: [0, 1, 2, 3, 4, 5, 8]
#
# Column: Parch
#   [low_cardinality] 7 unique values: [0, 1, 2, 3, 4, 5, 6]
#
# Column: PassengerId
#   [potential_id] unique ratio: 100.0%
#
# Column: Name
#   [potential_id] unique ratio: 100.0%
#
# --- VISIBLE_MISSING ---
# total_missing: 866
# ...
